# %%
import csv

# %%
with open ("D:\\22bca64\\python\\New folder\\product.csv",'w',newline='') as p:
    ac=csv.writer(p)
    header=["prod_no","prod_name","jan","feb","mar","apr","may","jun"]
    ac.writerow(header)
    for i in range(12):
        prod_no=int(input("Enter product no:"))
        prod_name=input("Enter product name:")
        jan=int(input("Enter product selling of jan:"))
        feb=int(input("Enter product selling of feb:"))
        mar=int(input("Enter product selling of mar:"))
        apr=int(input("Enter product selling of apr:"))
        may=int(input("Enter product selling of may:"))
        jun=int(input("Enter product selling of jun:"))
        record=[prod_no,prod_name,jan,feb,mar,apr,may,jun]
        ac.writerow(record)
# Out:
# Enter product no:1
# Enter product name:Laptop
# Enter product selling of jan:3900
# Enter product selling of feb:4000
# Enter product selling of mar:4100
# Enter product selling of apr:4200
# Enter product selling of may:4500
# Enter product selling of jun:4600
# Enter product no:2
# Enter product name:Hard disk
# Enter product selling of jan:2100
# Enter product selling of feb:2400
# Enter product selling of mar:2000
# Enter product selling of apr:2500
# Enter product selling of may:2600
# Enter product selling of jun:2500
# Enter product no:3
# Enter product name:SSD(Solid  State Drive)
# Enter product selling of jan:3500
# Enter product selling of feb:3200
# Enter product selling of mar:3600
# Enter product selling of apr:3800
# Enter product selling of may:3900
# Enter product selling of jun:4000
# Enter product no:4
# Enter product name:Keyboard
# Enter product selling of jan:2500
# Enter product selling of feb:2800
# Enter product selling of mar:2900
# ...

# %%
with open("D:\\22bca64\\python\\New folder\\product.csv",'r')as pf:
    content=csv.reader(pf)
    field=next(content)
    for i in content:
        print(i)

print("\nTotal no. of rows: %d"%(content.line_num))
print('Field names are:')
print(', '.join(field for field in header))
# Out:
# []
# ['1', 'Laptop', '3900', '4000', '4100', '4200', '4500', '4600']
# []
# ['2', 'Hard disk', '2100', '2400', '2000', '2500', '2600', '2500']
# []
# ['3', 'SSD(Solid  State Drive)', '3500', '3200', '3600', '3800', '3900', '4000']
# []
# ['4', 'Keyboard', '2500', '2800', '2900', '3000', '2800', '3500']
# []
# ['5', 'Mouse', '2400', '2600', '2800', '3000', '3100', '3200']
# []
# ['6', 'portable hard disk', '1200', '1500', '1800', '1900', '1200', '1400']
# []
# ['7', 'MotherBoard', '2200', '2400', '2600', '2800', '2900', '2100']
# []
# ['8', 'Fan', '2900', '2800', '2700', '2600', '2650', '25400']
# []
# ['9', 'RAM', '1900', '2000', '2200', '2400', '2600', '2800']
# []
# ['10', 'CD player', '1200', '1400', '1100', '900', '800', '950']
# []
# ['11', 'Pendrive', '2300', '2400', '2450', '300', '3100', '2900']
# []
# ['12', 'laptop case', '500', '350', '290', '200', '210', '240']
# []
#
# Total no. of rows: 26
# Field names are:
# prod_no, prod_name, jan, feb, mar, apr, may, jun

# %% [markdown]
# # <span style='color:red'>2.Create dataframe.

# %%
import pandas as pd
df=pd.read_csv("D:\\22bca64\\python\\New folder\\product.csv")
print(df)
# Out:
#     prod_no                prod_name   jan   feb   mar   apr   may    jun
# 0         1                   Laptop  3900  4000  4100  4200  4500   4600
# 1         2                Hard disk  2100  2400  2000  2500  2600   2500
# 2         3  SSD(Solid  State Drive)  3500  3200  3600  3800  3900   4000
# 3         4                 Keyboard  2500  2800  2900  3000  2800   3500
# 4         5                    Mouse  2400  2600  2800  3000  3100   3200
# 5         6       portable hard disk  1200  1500  1800  1900  1200   1400
# 6         7              MotherBoard  2200  2400  2600  2800  2900   2100
# 7         8                      Fan  2900  2800  2700  2600  2650  25400
# 8         9                      RAM  1900  2000  2200  2400  2600   2800
# 9        10                CD player  1200  1400  1100   900   800    950
# 10       11                 Pendrive  2300  2400  2450   300  3100   2900
# 11       12              laptop case   500   350   290   200   210    240

# %% [markdown]
# # <span style='color:red'>  3. Change Column Name Product No, Product Name, January, February, March, April, May, June.

# %%
df.columns=["Product_no","Product_name","January","February","March","April","May","June"]
print(df)
# Out:
#     Product_no             Product_name  January  February  March  April  \
# 0            1                   Laptop     3900      4000   4100   4200
# 1            2                Hard disk     2100      2400   2000   2500
# 2            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3            4                 Keyboard     2500      2800   2900   3000
# 4            5                    Mouse     2400      2600   2800   3000
# 5            6       portable hard disk     1200      1500   1800   1900
# 6            7              MotherBoard     2200      2400   2600   2800
# 7            8                      Fan     2900      2800   2700   2600
# 8            9                      RAM     1900      2000   2200   2400
# 9           10                CD player     1200      1400   1100    900
# 10          11                 Pendrive     2300      2400   2450    300
# 11          12              laptop case      500       350    290    200
#
#      May   June
# ...

# %% [markdown]
# # <span style='color:red'> 4. Add column "Total Sell" to count total of all month and "Average Sell"

# %%
df["Total sell"]=df["January"]+df["February"]+df["March"]+df["April"]+df["May"]+df["June"]
print(df)
# Out:
#     Product_no             Product_name  January  February  March  April  \
# 0            1                   Laptop     3900      4000   4100   4200
# 1            2                Hard disk     2100      2400   2000   2500
# 2            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3            4                 Keyboard     2500      2800   2900   3000
# 4            5                    Mouse     2400      2600   2800   3000
# 5            6       portable hard disk     1200      1500   1800   1900
# 6            7              MotherBoard     2200      2400   2600   2800
# 7            8                      Fan     2900      2800   2700   2600
# 8            9                      RAM     1900      2000   2200   2400
# 9           10                CD player     1200      1400   1100    900
# 10          11                 Pendrive     2300      2400   2450    300
# 11          12              laptop case      500       350    290    200
#
# ...

# %%
df["Average sell"]=df["Total sell"]/6
print(df)
# Out:
#     Product_no             Product_name  January  February  March  April  \
# 0            1                   Laptop     3900      4000   4100   4200
# 1            2                Hard disk     2100      2400   2000   2500
# 2            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3            4                 Keyboard     2500      2800   2900   3000
# 4            5                    Mouse     2400      2600   2800   3000
# 5            6       portable hard disk     1200      1500   1800   1900
# 6            7              MotherBoard     2200      2400   2600   2800
# 7            8                      Fan     2900      2800   2700   2600
# 8            9                      RAM     1900      2000   2200   2400
# 9           10                CD player     1200      1400   1100    900
# 10          11                 Pendrive     2300      2400   2450    300
# 11          12              laptop case      500       350    290    200
#
# ...

# %% [markdown]
# # <span style='color:red'> 5. Add 2 row at the end.

# %%
df.loc[12],df.loc[13]=[13,"portable keyboard",2200,2900,2100,2500,2900,3000,15600,2600.000000],[14,"Repair tool",2500,2900,3000,3300,3500,3550,18750,3125.000000]
print(df)
# Out:
#     Product_no             Product_name  January  February  March  April  \
# 0            1                   Laptop     3900      4000   4100   4200
# 1            2                Hard disk     2100      2400   2000   2500
# 2            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3            4                 Keyboard     2500      2800   2900   3000
# 4            5                    Mouse     2400      2600   2800   3000
# 5            6       portable hard disk     1200      1500   1800   1900
# 6            7              MotherBoard     2200      2400   2600   2800
# 7            8                      Fan     2900      2800   2700   2600
# 8            9                      RAM     1900      2000   2200   2400
# 9           10                CD player     1200      1400   1100    900
# 10          11                 Pendrive     2300      2400   2450    300
# 11          12              laptop case      500       350    290    200
# ...

# %% [markdown]
# # <span style='color:red'> 6. Add 2 row after 3rd row.

# %%
df.loc[2.5]=[15,"Displayport",2100,2200,2900,3000,2500,2900,15600,2600.000000]
df.loc[3.5]=[16,"Wifiadopter",1900,1500,1200,1100,2100,2000,9800,1633.333333]
print(df)
# Out:
#       Product_no             Product_name  January  February  March  April  \
# 0.0            1                   Laptop     3900      4000   4100   4200
# 1.0            2                Hard disk     2100      2400   2000   2500
# 2.0            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3.0            4                 Keyboard     2500      2800   2900   3000
# 4.0            5                    Mouse     2400      2600   2800   3000
# 5.0            6       portable hard disk     1200      1500   1800   1900
# 6.0            7              MotherBoard     2200      2400   2600   2800
# 7.0            8                      Fan     2900      2800   2700   2600
# 8.0            9                      RAM     1900      2000   2200   2400
# 9.0           10                CD player     1200      1400   1100    900
# 10.0          11                 Pendrive     2300      2400   2450    300
# ...

# %% [markdown]
# # <span style='color:red'> 7. Print first 5 row.

# %%
df.head()
# Out:
#      Product_no             Product_name  January  February  March  April  \
# 0.0           1                   Laptop     3900      4000   4100   4200
# 1.0           2                Hard disk     2100      2400   2000   2500
# 2.0           3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 3.0           4                 Keyboard     2500      2800   2900   3000
# 4.0           5                    Mouse     2400      2600   2800   3000
#
#       May  June  Total sell  Average sell
# 0.0  4500  4600       25300   4216.666667
# 1.0  2600  2500       14100   2350.000000
# 2.0  3900  4000       22000   3666.666667
# 3.0  2800  3500       17500   2916.666667
# 4.0  3100  3200       17100   2850.000000

# %% [markdown]
# # <span style='color:red'> 8. Print Last 5 row.

# %%
df.tail()
# Out:
#       Product_no       Product_name  January  February  March  April   May  \
# 11.0          12        laptop case      500       350    290    200   210
# 12.0          13  portable keyboard     2200      2900   2100   2500  2900
# 13.0          14        Repair tool     2500      2900   3000   3300  3500
# 2.5           15        Displayport     2100      2200   2900   3000  2500
# 3.5           16        Wifiadopter     1900      1500   1200   1100  2100
#
#       June  Total sell  Average sell
# 11.0   240        1790    298.333333
# 12.0  3000       15600   2600.000000
# 13.0  3550       18750   3125.000000
# 2.5   2900       15600   2600.000000
# 3.5   2000        9800   1633.333333

# %% [markdown]
# # <span style='color:red'> 9. Print row 6 to 10.

# %%
df.iloc[5:11]
# Out:
#       Product_no        Product_name  January  February  March  April   May  \
# 5.0            6  portable hard disk     1200      1500   1800   1900  1200
# 6.0            7         MotherBoard     2200      2400   2600   2800  2900
# 7.0            8                 Fan     2900      2800   2700   2600  2650
# 8.0            9                 RAM     1900      2000   2200   2400  2600
# 9.0           10           CD player     1200      1400   1100    900   800
# 10.0          11            Pendrive     2300      2400   2450    300  3100
#
#        June  Total sell  Average sell
# 5.0    1400        9000   1500.000000
# 6.0    2100       15000   2500.000000
# 7.0   25400       39050   6508.333333
# 8.0    2800       13900   2316.666667
# 9.0     950        6350   1058.333333
# 10.0   2900       13450   2241.666667

# %% [markdown]
# # <span style='color:red'> 10. Print only product name.

# %%
print(df.Product_name)
# Out:
# 0.0                      Laptop
# 1.0                   Hard disk
# 2.0     SSD(Solid  State Drive)
# 3.0                    Keyboard
# 4.0                       Mouse
# 5.0          portable hard disk
# 6.0                 MotherBoard
# 7.0                         Fan
# 8.0                         RAM
# 9.0                   CD player
# 10.0                   Pendrive
# 11.0                laptop case
# 12.0          portable keyboard
# 13.0                Repair tool
# 2.5                 Displayport
# 3.5                 Wifiadopter
# Name: Product_name, dtype: object

# %% [markdown]
# # <span style='color:red'> 11. Print sell of January month with product id and product name.

# %%
print(df[["Product_no","Product_name","January"]])
# Out:
#       Product_no             Product_name  January
# 0.0            1                   Laptop     3900
# 1.0            2                Hard disk     2100
# 2.0            3  SSD(Solid  State Drive)     3500
# 3.0            4                 Keyboard     2500
# 4.0            5                    Mouse     2400
# 5.0            6       portable hard disk     1200
# 6.0            7              MotherBoard     2200
# 7.0            8                      Fan     2900
# 8.0            9                      RAM     1900
# 9.0           10                CD player     1200
# 10.0          11                 Pendrive     2300
# 11.0          12              laptop case      500
# 12.0          13        portable keyboard     2200
# 13.0          14              Repair tool     2500
# 2.5           15              Displayport     2100
# 3.5           16              Wifiadopter     1900

# %% [markdown]
# # <span style='color:red'> 12. Print only those product id , product name where january sell is > 5000 and February sell is >8000

# %%
df[(df.January>1500) & (df.February>2000)][["Product_no","Product_name"]]
# Out:
#       Product_no             Product_name
# 0.0            1                   Laptop
# 1.0            2                Hard disk
# 2.0            3  SSD(Solid  State Drive)
# 3.0            4                 Keyboard
# 4.0            5                    Mouse
# 6.0            7              MotherBoard
# 7.0            8                      Fan
# 10.0          11                 Pendrive
# 12.0          13        portable keyboard
# 13.0          14              Repair tool
# 2.5           15              Displayport

# %% [markdown]
# # <span style='color:red'>13. Print record in sorting order of Product name.

# %%
print(df.sort_values(by=["Product_name"]))
# Out:
#       Product_no             Product_name  January  February  March  April  \
# 9.0           10                CD player     1200      1400   1100    900
# 2.5           15              Displayport     2100      2200   2900   3000
# 7.0            8                      Fan     2900      2800   2700   2600
# 1.0            2                Hard disk     2100      2400   2000   2500
# 3.0            4                 Keyboard     2500      2800   2900   3000
# 0.0            1                   Laptop     3900      4000   4100   4200
# 6.0            7              MotherBoard     2200      2400   2600   2800
# 4.0            5                    Mouse     2400      2600   2800   3000
# 10.0          11                 Pendrive     2300      2400   2450    300
# 8.0            9                      RAM     1900      2000   2200   2400
# 13.0          14              Repair tool     2500      2900   3000   3300
# ...

# %% [markdown]
# # <span style='color:red'> 14. Display only odd index number column record.

# %%
print(df.iloc[1::2])
# Out:
#       Product_no        Product_name  January  February  March  April   May  \
# 1.0            2           Hard disk     2100      2400   2000   2500  2600
# 3.0            4            Keyboard     2500      2800   2900   3000  2800
# 5.0            6  portable hard disk     1200      1500   1800   1900  1200
# 7.0            8                 Fan     2900      2800   2700   2600  2650
# 9.0           10           CD player     1200      1400   1100    900   800
# 11.0          12         laptop case      500       350    290    200   210
# 13.0          14         Repair tool     2500      2900   3000   3300  3500
# 3.5           16         Wifiadopter     1900      1500   1200   1100  2100
#
#        June  Total sell  Average sell
# 1.0    2500       14100   2350.000000
# 3.0    3500       17500   2916.666667
# 5.0    1400        9000   1500.000000
# 7.0   25400       39050   6508.333333
# 9.0     950        6350   1058.333333
# 11.0    240        1790    298.333333
# ...

# %% [markdown]
# # <span style='color:red'>15. Display alternate row.

# %%
print(df.iloc[::2])
# Out:
#       Product_no             Product_name  January  February  March  April  \
# 0.0            1                   Laptop     3900      4000   4100   4200
# 2.0            3  SSD(Solid  State Drive)     3500      3200   3600   3800
# 4.0            5                    Mouse     2400      2600   2800   3000
# 6.0            7              MotherBoard     2200      2400   2600   2800
# 8.0            9                      RAM     1900      2000   2200   2400
# 10.0          11                 Pendrive     2300      2400   2450    300
# 12.0          13        portable keyboard     2200      2900   2100   2500
# 2.5           15              Displayport     2100      2200   2900   3000
#
#        May  June  Total sell  Average sell
# 0.0   4500  4600       25300   4216.666667
# 2.0   3900  4000       22000   3666.666667
# 4.0   3100  3200       17100   2850.000000
# 6.0   2900  2100       15000   2500.000000
# 8.0   2600  2800       13900   2316.666667
# ...
